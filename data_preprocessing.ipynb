# %%
import pandas as pd
import zipfile

# %%
zip_file_path = "final_data/narrowresult.zip"

with zipfile.ZipFile(zip_file_path, 'r') as z:
    file_names = z.namelist()
    
    csv_file_name = [name for name in file_names if name.endswith('.csv')][0]
    
    with z.open(csv_file_name) as f:
        df = pd.read_csv(f, low_memory=False)

df.head()
# Out:
#   OrganizationIdentifier                             OrganizationFormalName  \
# 0              CALWR_WQX           California Department Of Water Resources
# 1                  CEDEN     California State Water Resources Control Board
# 2                21CABCH  Southern California Coastal Water Research Pro...
# 3                  CEDEN     California State Water Resources Control Board
# 4                  CEDEN     California State Water Resources Control Board
#
#                       ActivityIdentifier ActivityStartDate  \
# 0                  CALWR_WQX-BL13B658987        2013-05-07
# 1                      CEDEN--2146157048        2013-04-29
# 2  21CABCH-ENCINAL BEACH SOUTH-4/29/2013        2013-04-29
# 3                      CEDEN--2146149071        2013-05-20
# 4                      CEDEN--2145498327        2013-05-22
#
#   ActivityStartTime/Time ActivityStartTime/TimeZoneCode  \
# 0               10:45:00                            PST
# 1               13:00:00                            PST
# 2                    NaN                            NaN
# 3               09:15:00                            PST
# 4               10:02:00                            PST
#
#   MonitoringLocationIdentifier  ResultIdentifier  DataLoggerLine  \
# 0        CALWR_WQX-B9D75841349  STORET-476204739             NaN
# 1              CEDEN-207R00271  STORET-560281410             NaN
# 2  21CABCH-ENCINAL BEACH SOUTH  STORET-283378496             NaN
# 3                CEDEN-SMC4.34  STORET-832636092             NaN
# 4              CEDEN-202R00280  STORET-832787370             NaN
#
#   ResultDetectionConditionText  ... AnalysisEndTime/TimeZoneCode  \
# 0                          NaN  ...                          NaN
# 1                          NaN  ...                          NaN
# 2                          NaN  ...                          NaN
# 3                          NaN  ...                          NaN
# 4                          NaN  ...                          NaN
#
#   ResultLaboratoryCommentCode ResultLaboratoryCommentText  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#   ResultDetectionQuantitationLimitUrl LaboratoryAccreditationIndicator  \
# 0                                 NaN                              NaN
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                                 NaN                              NaN
#
#   LaboratoryAccreditationAuthorityName TaxonomistAccreditationIndicator  \
# 0                                  NaN                              NaN
# 1                                  NaN                              NaN
# 2                                  NaN                              NaN
# 3                                  NaN                              NaN
# 4                                  NaN                              NaN
#
#   TaxonomistAccreditationAuthorityName LabSamplePreparationUrl ProviderName
# 0                                  NaN                     NaN       STORET
# 1                                  NaN                     NaN       STORET
# 2                                  NaN                     NaN       STORET
# 3                                  NaN                     NaN       STORET
# 4                                  NaN                     NaN       STORET
#
# [5 rows x 78 columns]

# %%
zip_file_path = "final_data/biological_metadata.zip"

with zipfile.ZipFile(zip_file_path, 'r') as z:
    file_names = z.namelist()
    
    csv_file_name = [name for name in file_names if name.endswith('.csv')][0]
    
    with z.open(csv_file_name) as f:
        df_bio_metadata = pd.read_csv(f, low_memory=False)

df_bio_metadata.head()
# Out:
#   OrganizationIdentifier                             OrganizationFormalName  \
# 0              CALWR_WQX           California Department Of Water Resources
# 1                  CEDEN     California State Water Resources Control Board
# 2                21CABCH  Southern California Coastal Water Research Pro...
# 3                  CEDEN     California State Water Resources Control Board
# 4                  CEDEN     California State Water Resources Control Board
#
#                       ActivityIdentifier                  ActivityTypeCode  \
# 0                  CALWR_WQX-BL13B658987                    Sample-Routine
# 1                      CEDEN--2146157048  Sample-Composite Without Parents
# 2  21CABCH-ENCINAL BEACH SOUTH-4/29/2013                    Sample-Routine
# 3                      CEDEN--2146149071  Field Msr/Obs-Habitat Assessment
# 4                      CEDEN--2145498327                    Sample-Routine
#
#   ActivityMediaName ActivityMediaSubdivisionName ActivityStartDate  \
# 0             Water                          NaN        2013-05-07
# 1        Biological                          NaN        2013-04-29
# 2             Water                          NaN        2013-04-29
# 3           Habitat                          NaN        2013-05-20
# 4             Water                          NaN        2013-05-22
#
#   ActivityStartTime/Time ActivityStartTime/TimeZoneCode ActivityEndDate  ...  \
# 0               10:45:00                            PST             NaN  ...
# 1               13:00:00                            PST             NaN  ...
# 2                    NaN                            NaN             NaN  ...
# 3               09:15:00                            PST             NaN  ...
# 4               10:02:00                            PST             NaN  ...
#
#          LaboratoryName AnalysisStartDate ResultLaboratoryCommentText  \
# 0  DWR Bryte Laboratory        2013-05-15                         NaN
# 1                   NaN               NaN                         NaN
# 2                   NaN               NaN                         NaN
# 3                   NaN               NaN                         NaN
# 4               CALTEST        2013-06-03                         NaN
#
#    ResultDetectionQuantitationLimitUrl DetectionQuantitationLimitTypeName  \
# 0                                  NaN                                NaN
# 1                                  NaN                                NaN
# 2                                  NaN                                NaN
# 3                                  NaN                                NaN
# 4                                  NaN                                NaN
#
#   DetectionQuantitationLimitMeasure/MeasureValue  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    DetectionQuantitationLimitMeasure/MeasureUnitCode LabSamplePreparationUrl  \
# 0                                                NaN                     NaN
# 1                                                NaN                     NaN
# 2                                                NaN                     NaN
# 3                                                NaN                     NaN
# 4                                                NaN                     NaN
#
#            LastUpdated ProviderName
# 0  2015-10-06T06:48:42       STORET
# 1  2016-06-28T23:47:00       STORET
# 2  2014-01-21T13:30:20       STORET
# 3  2020-04-07T23:49:29       STORET
# 4  2020-04-08T00:14:49       STORET
#
# [5 rows x 81 columns]

# %%
df['ResultIdentifier'] = df['ResultIdentifier'].astype(str)
df_bio_metadata['ResultIdentifier'] = df_bio_metadata['ResultIdentifier'].astype(str)

# %%
df_joined = df.merge(df_bio_metadata, on='ResultIdentifier', how='inner')  # Use your desired join type
df_joined.head()
# Out:
#   OrganizationIdentifier_x                           OrganizationFormalName_x  \
# 0                CALWR_WQX           California Department Of Water Resources
# 1                    CEDEN     California State Water Resources Control Board
# 2                  21CABCH  Southern California Coastal Water Research Pro...
# 3                    CEDEN     California State Water Resources Control Board
# 4                    CEDEN     California State Water Resources Control Board
#
#                     ActivityIdentifier_x ActivityStartDate_x  \
# 0                  CALWR_WQX-BL13B658987          2013-05-07
# 1                      CEDEN--2146157048          2013-04-29
# 2  21CABCH-ENCINAL BEACH SOUTH-4/29/2013          2013-04-29
# 3                      CEDEN--2146149071          2013-05-20
# 4                      CEDEN--2145498327          2013-05-22
#
#   ActivityStartTime/Time_x ActivityStartTime/TimeZoneCode_x  \
# 0                 10:45:00                              PST
# 1                 13:00:00                              PST
# 2                      NaN                              NaN
# 3                 09:15:00                              PST
# 4                 10:02:00                              PST
#
#   MonitoringLocationIdentifier_x  ResultIdentifier  DataLoggerLine  \
# 0          CALWR_WQX-B9D75841349  STORET-476204739             NaN
# 1                CEDEN-207R00271  STORET-560281410             NaN
# 2    21CABCH-ENCINAL BEACH SOUTH  STORET-283378496             NaN
# 3                  CEDEN-SMC4.34  STORET-832636092             NaN
# 4                CEDEN-202R00280  STORET-832787370             NaN
#
#   ResultDetectionConditionText_x  ...      LaboratoryName_y  \
# 0                            NaN  ...  DWR Bryte Laboratory
# 1                            NaN  ...                   NaN
# 2                            NaN  ...                   NaN
# 3                            NaN  ...                   NaN
# 4                            NaN  ...               CALTEST
#
#   AnalysisStartDate_y ResultLaboratoryCommentText_y  \
# 0          2013-05-15                           NaN
# 1                 NaN                           NaN
# 2                 NaN                           NaN
# 3                 NaN                           NaN
# 4          2013-06-03                           NaN
#
#   ResultDetectionQuantitationLimitUrl_y DetectionQuantitationLimitTypeName  \
# 0                                   NaN                                NaN
# 1                                   NaN                                NaN
# 2                                   NaN                                NaN
# 3                                   NaN                                NaN
# 4                                   NaN                                NaN
#
#   DetectionQuantitationLimitMeasure/MeasureValue  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   DetectionQuantitationLimitMeasure/MeasureUnitCode LabSamplePreparationUrl_y  \
# 0                                               NaN                       NaN
# 1                                               NaN                       NaN
# 2                                               NaN                       NaN
# 3                                               NaN                       NaN
# 4                                               NaN                       NaN
#
#            LastUpdated ProviderName_y
# 0  2015-10-06T06:48:42         STORET
# 1  2016-06-28T23:47:00         STORET
# 2  2014-01-21T13:30:20         STORET
# 3  2020-04-07T23:49:29         STORET
# 4  2020-04-08T00:14:49         STORET
#
# [5 rows x 158 columns]

# %%
# Identify '_x' and '_y' columns
x_columns = [col for col in df_joined.columns if col.endswith('_x')]
y_columns = [col.replace('_x', '_y') for col in x_columns if col.replace('_x', '_y') in df_joined.columns]

# Compare '_x' and '_y' columns
mismatched_columns = {}
for x_col, y_col in zip(x_columns, y_columns):
    mismatch = df_joined[x_col] != df_joined[y_col]
    mismatch_count = mismatch.sum()
    if mismatch_count > 0:
        mismatched_columns[x_col] = mismatch_count

# Output mismatched columns and counts
if mismatched_columns:
    print("Mismatched columns and their counts:")
    for col, count in mismatched_columns.items():
        print(f"{col} vs {col.replace('_x', '_y')}: {count} mismatches")
else:
    print("All '_x' and '_y' columns match perfectly.")
# Out:
# Mismatched columns and their counts:
# ActivityStartTime/Time_x vs ActivityStartTime/Time_y: 69268 mismatches
# ActivityStartTime/TimeZoneCode_x vs ActivityStartTime/TimeZoneCode_y: 69268 mismatches
# ResultDetectionConditionText_x vs ResultDetectionConditionText_y: 563352 mismatches
# ResultSampleFractionText_x vs ResultSampleFractionText_y: 397647 mismatches
# ResultMeasureValue_x vs ResultMeasureValue_y: 111626 mismatches
# ResultMeasure/MeasureUnitCode_x vs ResultMeasure/MeasureUnitCode_y: 168697 mismatches
# MeasureQualifierCode_x vs MeasureQualifierCode_y: 671693 mismatches
# StatisticalBaseCode_x vs StatisticalBaseCode_y: 661056 mismatches
# ResultWeightBasisText_x vs ResultWeightBasisText_y: 611143 mismatches
# ResultTimeBasisText_x vs ResultTimeBasisText_y: 676038 mismatches
# ResultTemperatureBasisText_x vs ResultTemperatureBasisText_y: 670318 mismatches
# ResultParticleSizeBasisText_x vs ResultParticleSizeBasisText_y: 659662 mismatches
# DataQuality/BiasValue_x vs DataQuality/BiasValue_y: 676186 mismatches
# ResultCommentText_x vs ResultCommentText_y: 499371 mismatches
# USGSPCode_x vs USGSPCode_y: 468391 mismatches
# ResultDepthHeightMeasure/MeasureValue_x vs ResultDepthHeightMeasure/MeasureValue_y: 536241 mismatches
# ResultDepthHeightMeasure/MeasureUnitCode_x vs ResultDepthHeightMeasure/MeasureUnitCode_y: 536226 mismatches
# ResultDepthAltitudeReferencePointText_x vs ResultDepthAltitudeReferencePointText_y: 676186 mismatches
# SubjectTaxonomicName_x vs SubjectTaxonomicName_y: 598727 mismatches
# SampleTissueAnatomyName_x vs SampleTissueAnatomyName_y: 671226 mismatches
# ResultAnalyticalMethod/MethodIdentifier_x vs ResultAnalyticalMethod/MethodIdentifier_y: 228455 mismatches
# ResultAnalyticalMethod/MethodIdentifierContext_x vs ResultAnalyticalMethod/MethodIdentifierContext_y: 228455 mismatches
# ResultAnalyticalMethod/MethodName_x vs ResultAnalyticalMethod/MethodName_y: 228506 mismatches
# ResultAnalyticalMethod/MethodUrl_x vs ResultAnalyticalMethod/MethodUrl_y: 676186 mismatches
# LaboratoryName_x vs LaboratoryName_y: 361140 mismatches
# AnalysisStartDate_x vs AnalysisStartDate_y: 444938 mismatches
# ResultLaboratoryCommentText_x vs ResultLaboratoryCommentText_y: 642062 mismatches
# ResultDetectionQuantitationLimitUrl_x vs ResultDetectionQuantitationLimitUrl_y: 616737 mismatches
# LabSamplePreparationUrl_x vs LabSamplePreparationUrl_y: 676186 mismatches

# %%
df_joined["ActivityStartTime/Time_x"]
# Out:
# 0         10:45:00
# 1         13:00:00
# 2              NaN
# 3         09:15:00
# 4         10:02:00
#             ...
# 676181    08:23:00
# 676182    08:23:00
# 676183    08:23:00
# 676184    08:23:00
# 676185    08:23:00
# Name: ActivityStartTime/Time_x, Length: 676186, dtype: object

# %%
df_joined["ActivityStartTime/Time_y"]
# Out:
# 0         10:45:00
# 1         13:00:00
# 2              NaN
# 3         09:15:00
# 4         10:02:00
#             ...
# 676181    08:23:00
# 676182    08:23:00
# 676183    08:23:00
# 676184    08:23:00
# 676185    08:23:00
# Name: ActivityStartTime/Time_y, Length: 676186, dtype: object
