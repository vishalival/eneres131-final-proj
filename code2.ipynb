# %%
import zipfile
import pandas as pd

zip_file_path = "narrowresult.zip"

with zipfile.ZipFile(zip_file_path, 'r') as z:
    file_names = z.namelist()
    
    csv_file_name = [name for name in file_names if name.endswith('.csv')][0]
    
    with z.open(csv_file_name) as f:
        df = pd.read_csv(f)

df.head()
# Out:
# /var/folders/97/l1_w165s1z38tw82rlydjzp00000gn/T/ipykernel_35850/1058866281.py:17: DtypeWarning: Columns (10,13,15,19,20,22,31,33,34,36,38,40,43,48,60,64,65,70,71,72) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f)
#        OrganizationIdentifier  \
# 0                   CALWR_WQX
# 1                       CEDEN
# 2                     21CABCH
# 3                       CEDEN
# 4                       CEDEN
# ...                       ...
# 676181                USGS-CA
# 676182                USGS-CA
# 676183                USGS-CA
# 676184                USGS-CA
# 676185                USGS-CA
#
#                                    OrganizationFormalName  \
# 0                California Department Of Water Resources
# 1          California State Water Resources Control Board
# 2       Southern California Coastal Water Research Pro...
# 3          California State Water Resources Control Board
# 4          California State Water Resources Control Board
# ...                                                   ...
# 676181               USGS California Water Science Center
# 676182               USGS California Water Science Center
# 676183               USGS California Water Science Center
# 676184               USGS California Water Science Center
# 676185               USGS California Water Science Center
#
#                            ActivityIdentifier ActivityStartDate  \
# 0                       CALWR_WQX-BL13B658987        2013-05-07
# 1                           CEDEN--2146157048        2013-04-29
# 2       21CABCH-ENCINAL BEACH SOUTH-4/29/2013        2013-04-29
# 3                           CEDEN--2146149071        2013-05-20
# 4                           CEDEN--2145498327        2013-05-22
# ...                                       ...               ...
# 676181                     nwisca.01.02400110        2023-10-17
# 676182                     nwisca.01.02400110        2023-10-17
# 676183                     nwisca.01.02400110        2023-10-17
# 676184                     nwisca.01.02400110        2023-10-17
# 676185                     nwisca.01.02400110        2023-10-17
#
#        ActivityStartTime/Time ActivityStartTime/TimeZoneCode  \
# 0                    10:45:00                            PST
# 1                    13:00:00                            PST
# 2                         NaN                            NaN
# 3                    09:15:00                            PST
# 4                    10:02:00                            PST
# ...                       ...                            ...
# 676181               08:23:00                            PST
# 676182               08:23:00                            PST
# 676183               08:23:00                            PST
# 676184               08:23:00                            PST
# 676185               08:23:00                            PST
#
#        MonitoringLocationIdentifier  ResultIdentifier  DataLoggerLine  \
# 0             CALWR_WQX-B9D75841349  STORET-476204739             NaN
# 1                   CEDEN-207R00271  STORET-560281410             NaN
# 2       21CABCH-ENCINAL BEACH SOUTH  STORET-283378496             NaN
# 3                     CEDEN-SMC4.34  STORET-832636092             NaN
# 4                   CEDEN-202R00280  STORET-832787370             NaN
# ...                             ...               ...             ...
# 676181         USGS-373920122155201    NWIS-126552644             NaN
# 676182         USGS-373920122155201    NWIS-126552645             NaN
# 676183         USGS-373920122155201    NWIS-126552646             NaN
# 676184         USGS-373920122155201    NWIS-126552648             NaN
# 676185         USGS-373920122155201    NWIS-126552651             NaN
#
#        ResultDetectionConditionText  ... AnalysisEndTime/TimeZoneCode  \
# 0                               NaN  ...                          NaN
# 1                               NaN  ...                          NaN
# 2                               NaN  ...                          NaN
# 3                               NaN  ...                          NaN
# 4                               NaN  ...                          NaN
# ...                             ...  ...                          ...
# 676181                          NaN  ...                          NaN
# 676182                          NaN  ...                          NaN
# 676183                          NaN  ...                          NaN
# 676184                          NaN  ...                          NaN
# 676185                          NaN  ...                          NaN
#
#        ResultLaboratoryCommentCode ResultLaboratoryCommentText  \
# 0                              NaN                         NaN
# 1                              NaN                         NaN
# 2                              NaN                         NaN
# 3                              NaN                         NaN
# 4                              NaN                         NaN
# ...                            ...                         ...
# 676181                         NaN                         NaN
# 676182                         NaN                         NaN
# 676183                         NaN                         NaN
# 676184                         NaN                         NaN
# 676185                         NaN                         NaN
#
#        ResultDetectionQuantitationLimitUrl LaboratoryAccreditationIndicator  \
# 0                                      NaN                              NaN
# 1                                      NaN                              NaN
# 2                                      NaN                              NaN
# 3                                      NaN                              NaN
# 4                                      NaN                              NaN
# ...                                    ...                              ...
# 676181                                 NaN                              NaN
# 676182                                 NaN                              NaN
# 676183                                 NaN                              NaN
# 676184                                 NaN                              NaN
# 676185                                 NaN                              NaN
#
#        LaboratoryAccreditationAuthorityName TaxonomistAccreditationIndicator  \
# 0                                       NaN                              NaN
# 1                                       NaN                              NaN
# 2                                       NaN                              NaN
# 3                                       NaN                              NaN
# 4                                       NaN                              NaN
# ...                                     ...                              ...
# 676181                                  NaN                              NaN
# 676182                                  NaN                              NaN
# 676183                                  NaN                              NaN
# 676184                                  NaN                              NaN
# 676185                                  NaN                              NaN
#
#        TaxonomistAccreditationAuthorityName LabSamplePreparationUrl  \
# 0                                       NaN                     NaN
# 1                                       NaN                     NaN
# 2                                       NaN                     NaN
# 3                                       NaN                     NaN
# 4                                       NaN                     NaN
# ...                                     ...                     ...
# 676181                                  NaN                     NaN
# 676182                                  NaN                     NaN
# 676183                                  NaN                     NaN
# 676184                                  NaN                     NaN
# 676185                                  NaN                     NaN
#
#        ProviderName
# 0            STORET
# 1            STORET
# 2            STORET
# 3            STORET
# 4            STORET
# ...             ...
# 676181         NWIS
# 676182         NWIS
# 676183         NWIS
# 676184         NWIS
# 676185         NWIS
#
# [676186 rows x 78 columns]
